# %% [markdown]
# ### **Day-15:-**

# %% [markdown]
# ```
# seaborn:-

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
sns.scatterplot(x=df["sepal_length"],y=df["sepal_width"])
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x=df["sepal_length"],y=df["petal_length"])
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x=df["petal_length"],y=df["petal_width"])
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.distplot(df["sepal_length"])
# Out:
# C:\Users\Abhi\AppData\Local\Temp\ipykernel_18348\891408485.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["sepal_length"])
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.histplot(df["sepal_length"])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
df=sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x=df["total_bill"],y=df["tip"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df["smoker"].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.scatterplot(x=df.total_bill,y=df.tip,data=df,hue="smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x=df.total_bill,y=df.tip,data=df,hue="smoker")

# %%
sns.relplot(x=df.total_bill,y=df.tip,data=df,hue="size")

# %%
df["size"].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.relplot(x=df.total_bill,y=df.tip,data=df,style="size")

# %%
sns.relplot(x=df.total_bill,y=df.tip,data=df,style="size",hue="time")

# %%
sns.catplot(x="day",y="total_bill",data=df)

# %%
sns.catplot(x="smoker",y="tip",data=df)

# %%
sns.jointplot(x="total_bill",y="tip",data=df)

# %%
sns.pairplot(df)

# %%
sns.jointplot(df)
