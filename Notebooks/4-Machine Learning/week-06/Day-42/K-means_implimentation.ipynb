# %% [markdown]
# ## K-Means Practical Implimentation:-

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
x,y=make_blobs(n_samples=1000,centers=3,n_features=2,random_state=23)

# %%
x.shape
# Out:
# (1000, 2)

# %%
plt.scatter(x[:,0],x[:,1])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k,init="k-means++")
    kmeans.fit(x_train)
    wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [41167.283407539,
#  9544.872623190913,
#  1570.3723999827841,
#  1395.5763450172062,
#  1247.4433850150544,
#  1026.4356390016542,
#  960.45579430796,
#  803.6237947005664,
#  762.7931689264207,
#  642.8125063956289]

# %%
plt.plot(range(1,11),wcss)
plt.xticks(range(1,11))
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %% [markdown]
# k=3

# %%
kmeans=KMeans(n_clusters=3,init="k-means++")

# %%
y_labels=kmeans.fit_predict(x_train)

# %%
plt.scatter(x_train[:,0],x_train[:,1],c=y_labels)

# %%
y_label=kmeans.predict(x_test)

# %%
plt.scatter(x_test[:,0],x_test[:,1],c=y_label)

# %%
from kneed import kneeLocator
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from kneed import kneeLocator
#
# ImportError: cannot import name 'kneeLocator' from 'kneed' (e:\DATA SCIENCE 101 DAYS CHALENGE\abhi\Lib\site-packages\kneed\__init__.py)

# %%
pip install kneed
# Out:
# Requirement already satisfied: kneed in e:\data science 101 days chalenge\abhi\lib\site-packages (0.8.5)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\abhi\appdata\roaming\python\python312\site-packages (from kneed) (1.26.0)
# Requirement already satisfied: scipy>=1.0.0 in e:\data science 101 days chalenge\abhi\lib\site-packages (from kneed) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.
