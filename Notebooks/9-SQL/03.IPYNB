# %% [markdown]
# ## **SQL:-**

# %% [markdown]
# ➡️ SHOW DATABSE:-

# %%
SHOW DATABASES;

# %% [markdown]
# ➡️ CREATING A NEW DATABSE

# %%
CREATE DATABASE COLLEGE;

# %% [markdown]
# ➡️ WORKING WITH A DATABASE

# %%
USE COLLEGE;

# %% [markdown]
# ➡️ DELETING THE DATABASE

# %%
DROP DATABASE ABHISHEK;

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
USE COLLEGE;

# %% [markdown]
# ➡️ CREATING A NEW TABLE:-

# %%
CREATE TABLE STUDENT(
    ID INT,
    NAME VARCHAR(50),
    AGE INT,
    DEPARTMENT VARCHAR(50)
);

# %% [markdown]
# ➡️ HOW TO VERIFY OR SAW THE TABLE:-

# %%
-- Active: 1728450789429@@localhost@3306
DESC STUDENT;

# %% [markdown]
# ➡️ INSERTING THE DATA INTO GIVEN TABLE:-

# %%
INSERT INTO STUDENT(ID,NAME,AGE,`DEPARTMENT`) VALUES 
(1,'ABHISHEK UPADHYAY',23,'INFORMATION TECHNOLOGY'),
(2,'ABHISHEK UPADHYAY',23,'CIVIL'),
(3,'ANKIT UPADHYAY',23,'ELECTRICAL'),
(4,'ASHISH UPADHYAY',30,'INFORMATION TECHNOLOGY'),
(5,'SHILPA UPADHYAY',24,'INFORMATION TECHNOLOGY'),
(6,'AKASH UPADHYAY',24,'INFORMATION TECHNOLOGY');

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
SELECT * FROM STUDENT;
SELECT NAME,ID FROM STUDENT;

# %% [markdown]
# ➡️ WHERE KEYWORD:-

# %%
SELECT * FROM STUDENT WHERE ID=1 AND NAME='ABHISHEK UPADHYAY';

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
UPDATE STUDENT SET ID=2 WHERE NAME='ANKIT UPADHYAY' AND ID=1;
UPDATE STUDENT SET ID=3 WHERE NAME='ASHISH UPADHYAY' AND ID=1;
UPDATE STUDENT SET ID=4 WHERE NAME='SHILPA UPADHYAY' AND ID=1;
UPDATE STUDENT SET ID=5 WHERE NAME='AKASH UPADHYAY' AND ID=1;
UPDATE STUDENT SET ID=6 WHERE NAME='ABHISHEK UPADHYAY' AND ID=1 AND DEPARTMENT='CIVIL';
SELECT * FROM STUDENT;

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
CREATE TABLE STUDENT_INFORMATION(
    ID INT NOT NULL,
    NAME VARCHAR(50),
    AGE INT,
    DEPARTMENT VARCHAR(50) DEFAULT 'INFORMATION TECHNOLOGY',
    ADDRESS VARCHAR(50),
    EMAIL VARCHAR(50),
    MOB_NO VARCHAR(10)
);

# %%
DESC STUDENT_INFORMATION;

# %%
INSERT INTO STUDENT_INFORMATION VALUES
();

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
SHOW DATABASES;

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
CREATE TABLE STUDENT_INFORMATION(
    ID INT PRIMARY KEY NOT NULL,
    
)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
CREATE DATABASE BANK_DB;

# %%
-- Active: 1728450789429@@localhost@3306
CREATE TABLE EMPLOYEES(
EMP_ID INT PRIMARY KEY AUTO_INCREMENT,
NAME VARCHAR(50) NOT NULL,
DESIG VARCHAR(50) DEFAULT 'Probation',
DEPT VARCHAR(50)
);

# %%
DESC EMPLOYEES;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
INSERT INTO STUDENT_INFORMATION VALUES
(1, 'John Doe', 20, 'COMPUTER SCIENCE', '123 Elm St', 'john.doe1@example.com', '9876543210'),
(2, 'Jane Smith', 21, 'MECHANICAL', '456 Oak St', 'jane.smith2@example.com', '8765432109'),
(3, 'Alice Johnson', 19, 'ELECTRICAL', '789 Pine St', 'alice.johnson3@example.com', '7654321098'),
(4, 'Bob Brown', 22, 'INFORMATION TECHNOLOGY', '321 Maple St', 'bob.brown4@example.com', '6543210987'),
(5, 'Charlie Davis', 23, 'CIVIL', '654 Cedar St', 'charlie.davis5@example.com', '5432109876'),
(6, 'David Wilson', 20, 'COMPUTER SCIENCE', '234 Birch St', 'david.wilson6@example.com', '4321098765'),
(7, 'Emily White', 21, 'MECHANICAL', '567 Spruce St', 'emily.white7@example.com', '3210987654'),
(8, 'Frank Green', 22, 'ELECTRICAL', '890 Cherry St', 'frank.green8@example.com', '2109876543'),
(9, 'Grace Hall', 20, 'INFORMATION TECHNOLOGY', '123 Walnut St', 'grace.hall9@example.com', '1098765432'),
(10, 'Hannah Lee', 23, 'CIVIL', '456 Chestnut St', 'hannah.lee10@example.com', '9876543211'),
(11, 'Ivy Scott', 20, 'COMPUTER SCIENCE', '789 Ash St', 'ivy.scott11@example.com', '8765432102'),
(12, 'Jack Moore', 22, 'MECHANICAL', '321 Fir St', 'jack.moore12@example.com', '7654321093'),
(13, 'Karen Taylor', 21, 'ELECTRICAL', '654 Palm St', 'karen.taylor13@example.com', '6543210984'),
(14, 'Louis Anderson', 19, 'INFORMATION TECHNOLOGY', '234 Willow St', 'louis.anderson14@example.com', '5432109875'),
(15, 'Megan Thomas', 23, 'CIVIL', '567 Sycamore St', 'megan.thomas15@example.com', '4321098766');

# %%
SELECT * FROM STUDENT_INFORMATION;
SELECT * FROM STUDENT_INFORMATION;

# %%
SHOW DATABASES;

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
SELECT * FROM STUDENT_INFORMATION;

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
SELECT NAME,CHAR_LENGTH(MOB_NO) AS NO_LENGTH
FROM STUDENT_INFORMATION;

# %%
SELECT * FROM EMPLOYEES

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
-- Active: 1728450789429@@localhost@3306
SHOW DATABASES;

# %%
USE COLLEGE;
