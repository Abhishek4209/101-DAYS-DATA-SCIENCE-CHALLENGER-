# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv(r'E:\DATA SCIENCE 101 DAYS CHALENGE\Notebooks\7-Time-Series\TSLA.CSV')

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close     Volume  \
# 0  2019-05-21  39.551998  41.480000  39.208000  41.015999   90019500
# 1  2019-05-22  39.820000  40.787998  38.355999  38.546001   93426000
# 2  2019-05-23  38.868000  39.894001  37.243999  39.098000  132735500
# 3  2019-05-24  39.966000  39.995998  37.750000  38.125999   70683000
# 4  2019-05-28  38.240002  39.000000  37.570000  37.740002   51564500
#
#    Dividends  Stock Splits
# 0          0           0.0
# 1          0           0.0
# 2          0           0.0
# 3          0           0.0
# 4          0           0.0

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Abhishek Upadhyay - Data Science Resume</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             line-height: 1.6;
#             margin: 0;
#             padding: 0;
#             background-color: #f4f4f4;
#             color: #333;
#         }
#
#         .container {
#             max-width: 900px;
#             margin: 20px auto;
#             padding: 20px;
#             background-color: #fff;
#             box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
#         }
#
#         h1, h2, h3 {
#             margin-top: 0;
#             color: #333;
#         }
#
#         .contact-info, .skills, .education, .experience, .projects, .references {
#             margin-bottom: 20px;
#         }
#
#         ul {
#             list-style-type: none;
#             padding: 0;
#         }
#
#         ul li {
#             margin-bottom: 10px;
#         }
#
#         a {
#             color: #0066cc;
#             text-decoration: none;
#         }
#
#         a:hover {
#             text-decoration: underline;
#         }
#
#         .section-title {
#             font-size: 20px;
#             border-bottom: 2px solid #333;
#             padding-bottom: 5px;
#             margin-bottom: 10px;
#         }
#
#         .container p {
#             margin: 0;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="container">
#         <header>
#             <h1>Abhishek Upadhyay</h1>
#             <div class="contact-info">
#                 <p>Email: <a href="mailto:abhishekupadhyay9336@gmail.com">abhishekupadhyay9336@gmail.com</a></p>
#                 <p>Phone: 9336821380</p>
#                 <p>LinkedIn: <a href="https://www.linkedin.com/in/abhishek-upadhyay-35b183259/" target="_blank">LinkedIn Profile</a></p>
#                 <p>GitHub: <a href="https://github.com/Abhishek4209" target="_blank">GitHub Profile</a></p>
#             </div>
#         </header>
#
#         <section class="objective">
#             <h2 class="section-title">Objective</h2>
#             <p>Motivated Data Science enthusiast with a strong foundation in Python, Machine Learning, Deep Learning, and NLP, seeking to leverage my skills in a challenging role that supports data-driven decision-making.</p>
#         </section>
#
#         <section class="skills">
#             <h2 class="section-title">Skills</h2>
#             <ul>
#                 <li><strong>Programming Languages:</strong> Python (v3.12)</li>
#                 <li><strong>Machine Learning:</strong> Ensemble Learning, Gaussian Naive Bayes, Feature Engineering, Model Deployment</li>
#                 <li><strong>Deep Learning:</strong> Neural Networks, CNN, OpenCV</li>
#                 <li><strong>NLP:</strong> Fake News Detection, Text Classification</li>
#                 <li><strong>Tools:</strong> Pandas, NumPy, Scikit-learn, TensorFlow, Keras, Power BI, SQL, Flask</li>
#                 <li><strong>Others:</strong> Web Scraping, Image Processing, OOP, Probability, Statistics, Calculus, Linear Algebra</li>
#             </ul>
#         </section>
#
#         <section class="education">
#             <h2 class="section-title">Education</h2>
#             <p><strong>B.Tech in Information Technology</strong></p>
#             <p>Rajkiya Engineering College Ambedkar Nagar | Graduated: 2023</p>
#         </section>
#
#         <section class="certifications">
#             <h2 class="section-title">Certifications</h2>
#             <ul>
#                 <li><strong>Data Science Master</strong> – PW Skills</li>
#                 <li><strong>Machine Learning</strong> – Internshala</li>
#             </ul>
#         </section>
#
#         <section class="experience">
#             <h2 class="section-title">Work Experience</h2>
#
#             <div class="experience-item">
#                 <h3>Research Intern</h3>
#                 <p>Neo Research Consulting Pvt Ltd, Gurgaon | October 2023 - January 2024</p>
#                 <ul>
#                     <li>Researched and analyzed data for client projects, contributing to model building and deployment.</li>
#                 </ul>
#             </div>
#
#             <div class="experience-item">
#                 <h3>Machine Learning Intern</h3>
#                 <p>Ineuron | April 2024 - June 2024</p>
#                 <ul>
#                     <li>Developed machine learning models with a focus on modular coding and industry best practices.</li>
#                 </ul>
#             </div>
#
#             <div class="experience-item">
#                 <h3>Data Science Intern</h3>
#                 <p>PW Skills | February 2024 - Present</p>
#                 <ul>
#                     <li>Worked on machine learning and deep learning projects with hands-on coding and model deployment.</li>
#                 </ul>
#             </div>
#         </section>
#
#         <section class="projects">
#             <h2 class="section-title">Projects</h2>
#             <ul>
#                 <li><strong>Flipkart Web Scraping</strong> | Tools: Python, BeautifulSoup<br>
#                     Developed a Python script to scrape product data and images from Flipkart for further analysis.
#                 </li>
#                 <li><strong>Credit Card Default Prediction</strong> | Tools: Python, XGBoost, Flask<br>
#                     Built a machine learning model with an 82.03% accuracy using XGBoost. Deployed the model using Flask for real-time predictions.
#                 </li>
#                 <li><strong>Smart Attendance System</strong> | Tools: Python, TensorFlow, OpenCV<br>
#                     Developed a face recognition-based attendance system using deep learning and OpenCV.
#                 </li>
#                 <li><strong>Fake News Prediction</strong> | Tools: Python, NLP, Scikit-learn<br>
#                     Built an NLP model to predict fake news using text classification techniques.
#                 </li>
#             </ul>
#         </section>
#
#         <section class="references">
#             <h2 class="section-title">References</h2>
#             <p><strong>Sushant Mishra</strong></p>
#             <p>Director Data Scientist, Hero Phin Corp, Delhi</p>
#             <p>Email: <a href="mailto:sushant.mishra@outlook.com">sushant.mishra@outlook.com</a></p>
#         </section>
#     </div>
# </body>
#
# </html>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758 entries, 0 to 757
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          758 non-null    object
#  1   Open          758 non-null    float64
#  2   High          758 non-null    float64
#  3   Low           758 non-null    float64
#  4   Close         758 non-null    float64
#  5   Volume        758 non-null    int64
#  6   Dividends     758 non-null    int64
#  7   Stock Splits  758 non-null    float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 47.5+ KB

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         Date       Open       High        Low      Close     Volume  \
# 0 2019-05-21  39.551998  41.480000  39.208000  41.015999   90019500
# 1 2019-05-22  39.820000  40.787998  38.355999  38.546001   93426000
# 2 2019-05-23  38.868000  39.894001  37.243999  39.098000  132735500
# 3 2019-05-24  39.966000  39.995998  37.750000  38.125999   70683000
# 4 2019-05-28  38.240002  39.000000  37.570000  37.740002   51564500
#
#    Dividends  Stock Splits
# 0          0           0.0
# 1          0           0.0
# 2          0           0.0
# 3          0           0.0
# 4          0           0.0

# %%
df['Stock Splits'].value_counts()
# Out:
# Stock Splits
# 0.0    757
# 5.0      1
# Name: count, dtype: int64

# %%
plt.plot(df['Open'])
plt.plot(df['High'])
plt.plot(df['Low'])
plt.plot(df['Close'])
