# %% [markdown]
# ## Neural Network Perceptron:-
# ```
# 1.perceptron is Building Block of ANN.
# 2.Linear Classifier.
# ```
# ## Weight Updation:-
# ```
#
# W     = W     +  eta (Target o/p - predict O/p) * X
#  (new)   (old)                                      i
#
#
# ```
# * eta ---> Learning rate (0 to 1)

# %% [markdown]
# ![Alt text](\1.png)

# %% [markdown]
# ![Alt text](\2.png)

# %% [markdown]
# ![Screenshot 2024-04-17 093726.png](<attachment:Screenshot 2024-04-17 093726.png>)

# %% [markdown]
# ![Screenshot 2024-04-17 093853.png](<attachment:Screenshot 2024-04-17 093853.png>)

# %% [markdown]
# ![Screenshot 2024-04-17 094107.png](<attachment:Screenshot 2024-04-17 094107.png>)
